# %%
import pandas as pd 
import os
import matplotlib.pyplot as plt 
from mpl_toolkits.mplot3d import Axes3D

# %%
kf_file = 'trajectories/visual_inertial/KeyFrameTrajectory_with_loop.txt'

df = pd.read_csv(kf_file, delimiter=' ',header=None)
x = df[1].to_list()
y = df[2].to_list()
z = df[3].to_list()
df.head()
# Out:
#               0         1         2         3         4         5         6  \
# 0  2.120500e+10  0.436012 -7.347672  1.105614 -0.823220  0.004198 -0.002247
# 1  2.140500e+10  0.481403 -7.086802  1.118136 -0.823074  0.001875 -0.000653
# 2  2.170500e+10  0.546049 -6.688465  1.136298 -0.822814 -0.001624  0.001756
# 3  2.200500e+10  0.605880 -6.284385  1.153636 -0.822547 -0.005063  0.004154
# 4  2.230500e+10  0.660914 -5.878820  1.170113 -0.822274 -0.008440  0.006503
#
#           7
# 0  0.567702
# 1  0.567930
# 2  0.568306
# 3  0.568660
# 4  0.568992

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.figsize"] = 12.8, 9.6

ax = plt.axes(projection='3d')

# Data for a three-dimensional line
zline = np.linspace(0, 15, 1000)
xline = np.sin(zline)
yline = np.cos(zline)
ax.plot3D(xline, yline, zline, 'gray')

# Data for three-dimensional scattered points
zdata = 15 * np.random.random(100)
xdata = np.sin(zdata) + 0.1 * np.random.randn(100)
ydata = np.cos(zdata) + 0.1 * np.random.randn(100)
ax.scatter3D(xdata, ydata, zdata, c=zdata, cmap='Greens')

# %%
4715/714
# Out:
# 6.603641456582633

# %%
fig = plt.figure(figsize=(20,16))
ax = fig.add_subplot(111, projection='3d')

# Scatter plot
ax.scatter(x, y, z, c='r', marker='o')
plt.show()

# %%
plt.plot(x,y)
plt.plot(y,z)
plt.plot(z,x)

# %%
#gt
gt_file = '/home/ayon/Dataset/Varos/2021-08-17_SEQ1/vehicle0/ground_truth_vehicle0_poses/vehicle0_poses_euler.csv'
gt_df = pd.read_csv(gt_file)
gt_x = gt_df['s_x_vw'].to_list()
gt_y = gt_df['s_y_vw'].to_list()
gt_z = gt_df['s_z_vw'].to_list()

gt_df.head()
# Out:
#    # timestamp [ns]     s_x_vw     s_y_vw    s_z_vw  theta_x_vw    theta_y_vw  \
# 0         4999936.0 -20.650703 -19.451828  1.846878   -1.570796  3.637914e-08
# 1        10000000.0 -20.650703 -19.451828  1.846878   -1.570796  3.637914e-08
# 2        15000064.0 -20.650703 -19.451828  1.846878   -1.570796  3.637914e-08
# 3        20000000.0 -20.650703 -19.451828  1.846878   -1.570796  3.637914e-08
# 4        24999936.0 -20.650703 -19.451828  1.846878   -1.570796  3.637914e-08
#
#    theta_z_vw
# 0   -2.158425
# 1   -2.158425
# 2   -2.158425
# 3   -2.158425
# 4   -2.158425

# %%
plt.plot(gt_x,gt_y)
plt.plot(gt_y,gt_z)
plt.plot(gt_z,gt_x)

# %%
fig = plt.figure(figsize=(20,16))
ax = fig.add_subplot(111, projection='3d')

# Scatter plot
ax.scatter(gt_x, gt_y, gt_z, c='r', marker='o')
plt.show()

# %%
import numpy as np
plt.plot(gt_x,gt_y)
plt.plot(6*np.array(z),-6*np.array(x))

# %%
plt.plot(gt_y,gt_z)
plt.plot(6*np.array(x),-6*np.array(y))

# %%
plt.plot(gt_y,gt_z)
plt.plot(-6*np.array(x),-6*np.array(y))

# %%
px = np.array(z)
py = -np.array(x)
pz = np.array(y)
